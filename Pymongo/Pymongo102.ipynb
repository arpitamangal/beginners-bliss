# %% [markdown]
# # Parse data stored in a Json file and save as a collection in MongoDB using pymongo

# %% [markdown]
# The format of "reviews_electronics.16.json" is:
#
# • reviewerID - ID of the reviewer, e.g. A2SUAM1J3GNN3B
#
# • asin - ID of the product, e.g. 0000013714
#
# • reviewerName - name of the reviewer
#
# • helpful - helpfulness rating of the review, e.g. 2/3
#
# • reviewText - text of the review
#
# • overall - rating of the product
#
# • summary - summary of the review
#
# • unixReviewTime - time of the review

# %%
from pymongo import MongoClient
import pymongo

# %%
#client = MongoClient(‘localhost’, 27017)
client = MongoClient("mongodb://localhost:27017/")

# %%
#create a MongoDB DB called "amazon"
database= client["amazon"]
#create a collection "reviews" in the database "amazon"
collection = database["reviews"]

# %% [markdown]
# ### reads json file and uploads each review as a separate document to the collection "reviews" in the DB "amazon".

# %%
#read json file and uploads each review as a separate document to the collection "reviews" in the DB "amazon".
json_file = open("reviews_electronics.16.json")
for element in json_file:
    element_dict = json.loads(element)
    collection.insert_one(element_dict)

# %% [markdown]
# ### use MongoDB's map reduce function to build a new collection "avg_scores" that averages review scores by product ("asin")

# %%
map_fxn = """function(){emit(this.asin, this.helpful[0])};"""
reduce_fxn = """function(key, value){return Array.avg(value);};"""
database.reviews.map_reduce(map_fxn,reduce_fxn,"avg_scores")
#print the first 100 entries of "avg_scores" to screen.
for record in database.avg_scores.find().limit(100):
    print(record)
# Out:
# {'_id': 'B00HVRB6V2', 'value': 0.0}
# {'_id': 'B00FCRH4LE', 'value': 1.0}
# {'_id': 'B00HPMCN8S', 'value': 6.666666666666667}
# {'_id': 'B00HNXZXYU', 'value': 0.0}
# {'_id': 'B00IOQOABM', 'value': 0.0}
# {'_id': 'B00EZ8CWVS', 'value': 0.0}
# {'_id': 'B00EPDMDZ8', 'value': 10.294117647058824}
# {'_id': 'B00I4YTC1M', 'value': 0.0}
# {'_id': 'B00I0MKCOO', 'value': 0.6666666666666666}
# {'_id': 'B00GZAOAVE', 'value': 0.0}
# {'_id': 'B00HUZTX4W', 'value': 1.6666666666666667}
# {'_id': 'B00J3UL4QW', 'value': 0.0}
# {'_id': 'B00IIP37HC', 'value': 0.0}
# {'_id': 'B00F71CQ9K', 'value': 0.0}
# {'_id': 'B00FEDQGN8', 'value': 1.0}
# {'_id': 'B00JI7QMJ4', 'value': 0.0}
# {'_id': 'B00HK8VB0S', 'value': 3.0}
# {'_id': 'B00HHZTCEQ', 'value': 0.3333333333333333}
# {'_id': 'B00FKCNMSK', 'value': 0.0}
# {'_id': 'B00HDPEEH0', 'value': 0.0}
# {'_id': 'B00HYKF9XM', 'value': 0.875}
# {'_id': 'B00H06VXGC', 'value': 0.0}
# {'_id': 'B00EQFIBTW', 'value': 0.5}
# {'_id': 'B00GFXTBNS', 'value': 0.8}
# {'_id': 'B00HNP59FQ', 'value': 0.3333333333333333}
# {'_id': 'B00GQTDOC0', 'value': 0.2608695652173913}
# {'_id': 'B00HEYVAN6', 'value': 5.684615384615385}
# {'_id': 'B00FP5VKY0', 'value': 0.25}
# {'_id': 'B00J3MFHXG', 'value': 0.4}
# {'_id': 'B00KG5T4C4', 'value': 0.0}
# {'_id': 'B00G41BFJY', 'value': 2.2857142857142856}
# {'_id': 'B00KTE7GMW', 'value': 0.0}
# {'_id': 'B00FIJQIN6', 'value': 0.0}
# {'_id': 'B00E6GAZZO', 'value': 1.0}
# {'_id': 'B00KD8WUJ8', 'value': 0.0}
# {'_id': 'B00HWQ7TG8', 'value': 0.0}
# {'_id': 'B00GSV9QNM', 'value': 1.0}
# {'_id': 'B00F2POE2I', 'value': 0.0}
# {'_id': 'B00EVWICX0', 'value': 0.0}
# {'_id': 'B00FJ8JHYI', 'value': 1.0049261083743843}
# {'_id': 'B00HUJWSTU', 'value': 0.2}
# {'_id': 'B00I0CGCZC', 'value': 0.0}
# {'_id': 'B00FXL1UNC', 'value': 0.0}
# {'_id': 'B00FHK5MR4', 'value': 0.0}
# {'_id': 'B00F2CVPBE', 'value': 0.0}
# {'_id': 'B00G0O7ASU', 'value': 1.0}
# {'_id': 'B00EIPYLD0', 'value': 0.0}
# {'_id': 'B00GOBD2WW', 'value': 0.3333333333333333}
# {'_id': 'B00HG6W6A8', 'value': 1.0}
# {'_id': 'B00FU2W9OS', 'value': 0.0}
# {'_id': 'B00HUG5D9U', 'value': 0.0}
# {'_id': 'B00IX01ZL2', 'value': 0.0}
# {'_id': 'B00IXEZDFW', 'value': 0.2}
# {'_id': 'B00FS96DJK', 'value': 0.5666666666666667}
# {'_id': 'B00HO5LDNC', 'value': 0.0}
# {'_id': 'B00EHCR4ME', 'value': 0.0}
# {'_id': 'B00JV4WM6Q', 'value': 0.0}
# {'_id': 'B00GGC0OR0', 'value': 0.25}
# {'_id': 'B00GH3HTYE', 'value': 0.0}
# {'_id': 'B00E7JIRXC', 'value': 0.0}
# {'_id': 'B00HZDTT7U', 'value': 2.2857142857142856}
# {'_id': 'B00HPBTOM2', 'value': 0.0}
# {'_id': 'B00FZM2ZHE', 'value': 0.3333333333333333}
# {'_id': 'B00GAVWDWG', 'value': 0.5}
# {'_id': 'B00FSV78J2', 'value': 0.0}
# {'_id': 'B00EJQJOKI', 'value': 0.0}
# {'_id': 'B00FM3RV84', 'value': 0.0}
# {'_id': 'B00F518Y6Q', 'value': 0.0}
# {'_id': 'B00G618EMI', 'value': 1.0}
# {'_id': 'B00H7KYFG6', 'value': 0.0}
# {'_id': 'B00FVRU5AM', 'value': 0.0}
# {'_id': 'B00GB3FDOS', 'value': 0.0}
# {'_id': 'B00F4THD5C', 'value': 0.5271317829457365}
# {'_id': 'B00FISIEXO', 'value': 0.0}
# {'_id': 'B00GHRJO20', 'value': 0.0}
# {'_id': 'B00GOKB14O', 'value': 0.0}
# {'_id': 'B00IO01LZG', 'value': 0.0}
# {'_id': 'B00KFBX9XY', 'value': 0.7142857142857143}
# {'_id': 'B00EO0I1US', 'value': 0.0}
# {'_id': 'B00HX7K5FI', 'value': 0.5}
# {'_id': 'B00GOIKCXM', 'value': 0.0}
# {'_id': 'B00JKF69N8', 'value': 0.5}
# {'_id': 'B00KAUA3B6', 'value': 0.0}
# {'_id': 'B00FAPHJ54', 'value': 0.23076923076923078}
# {'_id': 'B00FE2IO48', 'value': 0.3333333333333333}
# {'_id': 'B00FNR9FJW', 'value': 0.0}
# {'_id': 'B00GNNK97W', 'value': 1.0}
# {'_id': 'B00GRW0T6U', 'value': 3.75}
# {'_id': 'B00F6FYZQ4', 'value': 0.0}
# {'_id': 'B00GRUASX6', 'value': 0.0}
# {'_id': 'B00FA6BLZC', 'value': 0.75}
# {'_id': 'B00GULDSNO', 'value': 0.0}
# {'_id': 'B00FMSCDRS', 'value': 0.0}
# {'_id': 'B00GH39GLS', 'value': 0.5}
# {'_id': 'B00IPZBORA', 'value': 0.0}
# {'_id': 'B00F8W9YKW', 'value': 0.0}
# {'_id': 'B00FKT5E0M', 'value': 0.0}
# {'_id': 'B00H3TCFH2', 'value': 0.0}
# {'_id': 'B00IWKGXLK', 'value': 0.0}
# {'_id': 'B00FJEDT64', 'value': 0.875}

# %% [markdown]
# ### use MongoDB's map reduce function to build a new collection "weighted_avg_scores" that averages review scores by product ("asin"), weighted by the number of votes + 1 (the second number + 1).

# %%
map_fxn = """function(){emit(this.asin, {num:(this.helpful[0]*(this.helpful[1]+1)),deno:(this.helpful[1]+1)})};"""

reduce_fxn = """function reduce(key, values) {
    var num = 0;
    var deno = 0;

    values.forEach(function(value) {
        num += value.num;
        deno += value.deno;
    });
    
    
    return {weighted_avg_scores: num/deno};
};"""


database.reviews.map_reduce(map_fxn,reduce_fxn,"weighted_avg_scores")

#print the first 100 entires of "weighted_avg_scores" to screen.
for record in database.weighted_avg_scores.find().limit(100):
    print(record)
# Out:
# {'_id': 'B00IZ4LXXG', 'value': {'weighted_avg_scores': 1.0}}
# {'_id': 'B00FP3X8GA', 'value': {'weighted_avg_scores': 2.0}}
# {'_id': 'B00EOX4T74', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GURPEVC', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00F07T7OI', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GWLLRMQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EEEPPJO', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00F3I7HNM', 'value': {'weighted_avg_scores': 1.625}}
# {'_id': 'B00E9JLFX4', 'value': {'weighted_avg_scores': 0.6}}
# {'_id': 'B00GN940GM', 'value': {'weighted_avg_scores': 0.6666666666666666}}
# {'_id': 'B00G3R2XR2', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00KMVJR60', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EQ1V4XQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GLLAUIO', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HXE4H28', 'value': {'weighted_avg_scores': 6.8}}
# {'_id': 'B00J4QLBXG', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00IDQQYTY', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FQW5BGA', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GCDJBMM', 'value': {'weighted_avg_scores': 5.015384615384615}}
# {'_id': 'B00E77HDT8', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HKCBT3S', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FCKCSGC', 'value': {'weighted_avg_scores': 2.0}}
# {'_id': 'B00E9I9G1I', 'value': {'weighted_avg_scores': 0.6666666666666666}}
# {'_id': 'B00GPUFAB8', 'value': {'weighted_avg_scores': 3.3333333333333335}}
# {'_id': 'B00GOILZ8I', 'value': {'weighted_avg_scores': 1.0}}
# {'_id': 'B00FMI1LDK', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EKQHTM2', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00G8T7K14', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HSP6ABI', 'value': {'weighted_avg_scores': 0.42857142857142855}}
# {'_id': 'B00HOX2X4W', 'value': {'weighted_avg_scores': 1.5}}
# {'_id': 'B00EZJY15M', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GRD0D5G', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EAYGKW4', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GG2DEF4', 'value': {'weighted_avg_scores': 3.0}}
# {'_id': 'B00GR9SXWA', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00I0H235U', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00IJS6YRI', 'value': {'weighted_avg_scores': 1.5}}
# {'_id': 'B00JCOF672', 'value': {'weighted_avg_scores': 4.192771084337349}}
# {'_id': 'B00EEWIUXY', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00JA1NVRE', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FNX0S9W', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FL4O952', 'value': {'weighted_avg_scores': 1.2857142857142858}}
# {'_id': 'B00G97LCYQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HG3LP9E', 'value': {'weighted_avg_scores': 0.6666666666666666}}
# {'_id': 'B00FK5527Q', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FWOR638', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00IBV9I7G', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GH18HW4', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HD9IAOY', 'value': {'weighted_avg_scores': 2.0}}
# {'_id': 'B00JMVUCT2', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00H7KD5KI', 'value': {'weighted_avg_scores': 0.25}}
# {'_id': 'B00EXIQ0ZY', 'value': {'weighted_avg_scores': 4.046511627906977}}
# {'_id': 'B00KQ4LNJC', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HP3II4U', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00KAV17D8', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EMYGODW', 'value': {'weighted_avg_scores': 11.2}}
# {'_id': 'B00FNNLYU4', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00E9LG4TW', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00E6OQKYQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EQ20CB0', 'value': {'weighted_avg_scores': 2.2427184466019416}}
# {'_id': 'B00GJED6KW', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00I3MQ2WW', 'value': {'weighted_avg_scores': 2.0}}
# {'_id': 'B00HMD97YI', 'value': {'weighted_avg_scores': 0.8888888888888888}}
# {'_id': 'B00FDLLVIQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00ENJKVF8', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00HMBRXPA', 'value': {'weighted_avg_scores': 5.8}}
# {'_id': 'B00E9E5HOM', 'value': {'weighted_avg_scores': 0.5}}
# {'_id': 'B00FN2Q9OQ', 'value': {'weighted_avg_scores': 1.0}}
# {'_id': 'B00FQJ9MCC', 'value': {'weighted_avg_scores': 2.0}}
# {'_id': 'B00GYURT68', 'value': {'weighted_avg_scores': 1.6}}
# {'_id': 'B00GYQYY4W', 'value': {'weighted_avg_scores': 0.42105263157894735}}
# {'_id': 'B00GGU6WX2', 'value': {'weighted_avg_scores': 1.6363636363636365}}
# {'_id': 'B00EQ7UR8I', 'value': {'weighted_avg_scores': 1.7272727272727273}}
# {'_id': 'B00GVHJ5LG', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GAM1YKM', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FB6MHW2', 'value': {'weighted_avg_scores': 1.7241379310344827}}
# {'_id': 'B00F2LLTX4', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GFFJDMA', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00G54LVHQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00GNJXXAQ', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00H4DFVHI', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FYWY0V4', 'value': {'weighted_avg_scores': 0.6666666666666666}}
# {'_id': 'B00H3DH3JI', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00H0AL7GY', 'value': {'weighted_avg_scores': 0.4}}
# {'_id': 'B00L65M0Y2', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00E4LBZZK', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EDNU7N0', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00IZ41GWY', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FY98XOW', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00J2IIYW2', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00FL4RMTM', 'value': {'weighted_avg_scores': 1.0}}
# {'_id': 'B00E9OE4QE', 'value': {'weighted_avg_scores': 0.25}}
# {'_id': 'B00EY6YMO6', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00E4WSPBG', 'value': {'weighted_avg_scores': 4.909090909090909}}
# {'_id': 'B00E98G5YO', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00F954PRA', 'value': {'weighted_avg_scores': 1.2}}
# {'_id': 'B00F93SK28', 'value': {'weighted_avg_scores': 2.1666666666666665}}
# {'_id': 'B00GJ8NM3O', 'value': {'weighted_avg_scores': 0.0}}
# {'_id': 'B00EZF1MRG', 'value': {'weighted_avg_scores': 1.3333333333333333}}
# {'_id': 'B00HWI4FZO', 'value': {'weighted_avg_scores': 2.303030303030303}}
